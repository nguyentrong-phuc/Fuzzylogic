# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyentrong-phuc/Tri_Tue_Nhan_Tao/blob/main/Artificial_neural_network_ipy_np.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nhận diện chữ số viết tay sử dụng dữ liệu data mnist
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.metrics import metrics

model=models.Sequential()
(train_image,train_labels),(test_image,test_labels)=mnist.load_data()

train_image=train_image.reshape((60000,28*28))
train_image=train_image.astype('float32')/255
test_image=test_image.reshape(10000,28*28)
test_image=test_image.astype('float32')/255

train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax',))
model.summary()

model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(train_image,train_labels,epochs=100,batch_size=128)

test_loss,test_ace=model.evaluate(test_image,test_labels)
print('Test loss:',test_loss)
print('Test accuracy :',test_ace)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 512)               401920
#
#  dense_3 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 [==============================] - 7s 14ms/step - loss: 0.2526 - accuracy: 0.9264
# Epoch 2/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1033 - accuracy: 0.9696
# Epoch 3/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0675 - accuracy: 0.9796
# Epoch 4/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0489 - accuracy: 0.9851
# Epoch 5/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0362 - accuracy: 0.9890
# Epoch 6/100
# ...

# %%
from keras import layers
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils import img_to_array
import numpy as np
img = load_img('/content/drive/MyDrive/Colab Notebooks/2.png',target_size=(28,28))
plt.imshow(img)
img=img_to_array(img)
img=img[:,:,0]
img=img.reshape(1,28*28)
img=img.astype('float32')
img=img/255
a=int(np.argmax(model.predict(img),axis=1))
print(a)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 2

# %%
# Nhận diện quần áo, sử dụng thư viện data fashion_mnist
from keras.datasets import fashion_mnist
from keras.utils import to_categorical
import keras.metrics as metrics 
from keras import models
from keras import layers
model=models.Sequential()
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils import img_to_array
import numpy as np

(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
class_name=['T-shirt/Top','Trouser','Pullover','Dress','Coat','Sandel','Shirt','Sneaker','Bag','Angleboot']

x_train=x_train.reshape((60000,28*28))
x_train=x_train.astype('float32')/255
x_test=x_test.reshape(10000,28*28)
x_test=x_test.astype('float32')/255

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

model.add(layers.Dense(512,activation='relu',input_shape=(28*28,)))
model.add(layers.Dense(10,activation='softmax',))
model.summary()

model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=100,batch_size=128)

#đánh giá các mô hình trên dữ liệu thử nghiệm thông qua evaluate() :
test_loss,test_ace=model.evaluate(x_test,y_test)
print('Test loss:',test_loss)
print('Test accuracy : ',test_ace)
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 512)               401920
#
#  dense_5 (Dense)             (None, 10)                5130
#
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.5549 - accuracy: 0.8021
# Epoch 2/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3801 - accuracy: 0.8619
# Epoch 3/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3368 - accuracy: 0.8761
# Epoch 4/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3093 - accuracy: 0.8865
# Epoch 5/100
# ...

# %%
img = load_img('/content/drive/MyDrive/Colab Notebooks/bag.png',target_size=(28,28))
plt.imshow(img)
img=img_to_array(img)
img=img[:,:,0]
img=img.reshape(1,28*28)
img=img.astype('float32')
img=img/255
a=int(np.argmax(model.predict(img),axis=1))
print(a)
print(class_name[a])
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 8
# Bag

# %%
# CIFAR 10
from keras.datasets import cifar10
from keras.utils import np_utils
from keras import models
from keras import layers
import matplotlib.pyplot as plt
from keras.utils import load_img
from keras.utils import img_to_array
import numpy as np

(x_train,y_train),(x_test,y_test)=cifar10.load_data()

x_train=x_train.reshape((50000,32*32*3))
x_train=x_train.astype('float32')/255
x_test=x_test.reshape(10000,32*32*3)
x_test=x_test.astype('float32')/255

y_train=np_utils.to_categorical(y_train,10)
y_test=np_utils.to_categorical(y_test,10)

model=models.Sequential()
model.add(layers.Dense(512,activation='relu',input_shape=(32*32*3,)))
model.add(layers.Dense(512,activation='relu',))
model.add(layers.Dense(10,activation='softmax',))

import keras.metrics as metrics 
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=100,batch_size=128)

model.save('ABC.h5')
from keras.models import load_model
model1=load_model('ABC.h5')

test_loss,test_ace=model.evaluate(x_test,y_test)
print('Test loss:',test_loss)
print('Test accuracy : ',test_ace)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 17s 41ms/step - loss: 2.1262 - accuracy: 0.2621
# Epoch 2/100
# 391/391 [==============================] - 14s 36ms/step - loss: 1.7764 - accuracy: 0.3611
# Epoch 3/100
# 391/391 [==============================] - 14s 36ms/step - loss: 1.6778 - accuracy: 0.3991
# Epoch 4/100
# 391/391 [==============================] - 15s 38ms/step - loss: 1.6119 - accuracy: 0.4266
# Epoch 5/100
# 391/391 [==============================] - 15s 38ms/step - loss: 1.5579 - accuracy: 0.4448
# Epoch 6/100
# 391/391 [==============================] - 15s 38ms/step - loss: 1.5185 - accuracy: 0.4584
# Epoch 7/100
# 391/391 [==============================] - 14s 36ms/step - loss: 1.4791 - accuracy: 0.4738
# Epoch 8/100
# 391/391 [==============================] - 15s 37ms/step - loss: 1.4499 - accuracy: 0.4853
# Epoch 9/100
# 391/391 [==============================] - 14s 36ms/step - loss: 1.4204 - accuracy: 0.4951
# Epoch 10/100
# ...

# %%
img = load_img('/content/drive/MyDrive/Colab Notebooks/plane.png',target_size=(32,32,3))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
a=int(np.argmax(model1.predict(img),axis=1))
class_name=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
print(class_name[a])
# Out:
# 1/1 [==============================] - 0s 53ms/step
# airplane
